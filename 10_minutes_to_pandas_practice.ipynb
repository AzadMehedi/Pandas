# %% [markdown]
# <a href="https://colab.research.google.com/github/AzadMehedi/Pandas/blob/main/10_minutes_to_pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

#Object creation
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
#Creating a DataFrame by passing a NumPy array, with a datetime index and labeled columns:
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.472144  1.962587 -0.505662 -0.136562
# 2013-01-02  1.073427 -1.581209  0.012019 -1.232952
# 2013-01-03 -0.055263 -0.747325 -0.885778 -0.141106
# 2013-01-04  0.991484  0.229064  0.798565 -0.846814
# 2013-01-05  0.297961  1.310868 -0.230209  0.345082
# 2013-01-06  0.180598  0.901565 -2.296566  0.440790

# %%
#Creating a DataFrame by passing a dictionary of objects that can be converted into a series-like structure:
import pandas as pd
import numpy as np

df2 = pd.DataFrame({
    'A':1.0,
    'B':pd.Timestamp('20220101'),
    'C':pd.Series(1, index=list(range(4)), dtype=('float32')),
    'D':np.array([3]*4, dtype='int32'),
    'E':pd.Categorical(['test','train','test','train']),
    'F':'foo',
})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2022-01-01  1.0  3   test  foo
# 1  1.0 2022-01-01  1.0  3  train  foo
# 2  1.0 2022-01-01  1.0  3   test  foo
# 3  1.0 2022-01-01  1.0  3  train  foo

# %%
#The columns of the resulting DataFrame have different dtypes:
#type(df2)
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# # Viewing data

# %%
#Here is how to view the top and bottom rows of the frame:

df = pd.read_csv(r'C:\Users\azadm\Downloads\dataset\data.csv')
#df.head()
df.head(10)
# Out:
#    Unnamed: 0  Goal_no Season                Competition      Matchday Venue  \
# 0           0        1    2/3              Liga Portugal             6     H
# 1           1        2    2/3              Liga Portugal             6     H
# 2           2        3    2/3              Liga Portugal             8     A
# 3           3        4    2/3  TaÃ§a de Portugal Placard  Fourth Round     H
# 4           4        5    2/3  TaÃ§a de Portugal Placard   Fifth Round     H
# 5           5        6    3/4             Premier League            11     H
# 6           6        7    3/4                     FA Cup   Fifth Round     H
# 7           7        8    3/4             Premier League            29     H
# 8           8        9    3/4             Premier League            32     A
# 9           9       10    3/4             Premier League            38     A
#
#                 Team                 Opponent Result Position Minute At_score  \
# 0        Sporting CP            Moreirense FC    3:0       LW     34      2:0
# 1        Sporting CP            Moreirense FC    3:0      NaN   90+5      3:0
# 2        Sporting CP              Boavista FC    1:2      NaN     88      1:2
# 3        Sporting CP             CD Estarreja    4:1      NaN     67      3:0
# 4        Sporting CP  FC Oliveira do Hospital    8:1      NaN     13      3:0
# 5  Manchester United            Portsmouth FC    3:0       RW     80      2:0
# 6  Manchester United          Manchester City    4:2       RW     74      3:0
# 7  Manchester United        Tottenham Hotspur    3:0      NaN     89      2:0
# 8  Manchester United          Birmingham City    1:2      NaN     60      1:1
# 9  Manchester United              Aston Villa    0:2      NaN      4      0:1
#
#         Type_of_goal
# 0           Solo run
# 1             Header
# 2  Right-footed shot
# 3   Left-footed shot
# 4                NaN
# 5   Direct free kick
# 6  Right-footed shot
# 7  Right-footed shot
# 8             Header
# 9  Right-footed shot

# %%
#df.tail()
df.tail(7)
# Out:
#      Unnamed: 0  Goal_no Season     Competition Matchday Venue  \
# 691         691      692  21/22  Premier League       29     H
# 692         692      693  21/22  Premier League       33     H
# 693         693      694  21/22  Premier League       33     H
# 694         694      695  21/22  Premier League       33     H
# 695         695      696  21/22  Premier League       34     A
# 696         696      697  21/22  Premier League       37     H
# 697         697      698  21/22  Premier League       35     H
#
#                   Team           Opponent Result Position Minute At_score  \
# 691  Manchester United  Tottenham Hotspur    3:2       CF     81      3:2
# 692  Manchester United       Norwich City    3:2       CF      7      1:0
# 693  Manchester United       Norwich City    3:2       CF     32      2:0
# 694  Manchester United       Norwich City    3:2       CF     76      3:2
# 695  Manchester United         Arsenal FC    3:1       CF     34      2:1
# 696  Manchester United         Chelsea FC    1:1       CF     62      1:1
# 697  Manchester United       Brentford FC    3:0       CF     61      2:0
#
#           Type_of_goal
# 691             Header
# 692  Right-footed shot
# 693             Header
# 694   Direct free kick
# 695   Left-footed shot
# 696  Right-footed shot
# 697            Penalty

# %%
#Display the index, columns:
df.index
# Out:
# RangeIndex(start=0, stop=698, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Goal_no', 'Season', 'Competition', 'Matchday', 'Venue',
#        'Team', 'Opponent', 'Result', 'Position', 'Minute', 'At_score',
#        'Type_of_goal'],
#       dtype='object')

# %%
#NumPy arrays have one dtype for the entire array, while pandas DataFrames have one dtype per column.
#When you call DataFrame.to_numpy(), pandas will find the NumPy dtype that can hold all of the dtypes in the DataFrame. This may end up being object, which requires casting every value to a Python object.
df.to_numpy()
# Out:
# array([[0, 1, '2/3', ..., '34', '2:0', 'Solo run'],
#        [1, 2, '2/3', ..., '90+5', '3:0', 'Header'],
#        [2, 3, '2/3', ..., '88', '1:2', 'Right-footed shot'],
#        ...,
#        [695, 696, '21/22', ..., '34', '2:1', 'Left-footed shot'],
#        [696, 697, '21/22', ..., '62', '1:1', 'Right-footed shot'],
#        [697, 698, '21/22', ..., '61', '2:0', 'Penalty']], dtype=object)

# %%
#describe() shows a quick statistic summary of your data:
df.describe()
# Out:
#        Unnamed: 0    Goal_no
# count   698.00000  698.00000
# mean    348.50000  349.50000
# std     201.63953  201.63953
# min       0.00000    1.00000
# 25%     174.25000  175.25000
# 50%     348.50000  349.50000
# 75%     522.75000  523.75000
# max     697.00000  698.00000

# %%
#Transposing your data: Transposing means change the column into row. That meansvice-versa
df.T
# Out:
#                         0              1                  2    \
# Unnamed: 0                0              1                  2
# Goal_no                   1              2                  3
# Season                  2/3            2/3                2/3
# Competition   Liga Portugal  Liga Portugal      Liga Portugal
# Matchday                  6              6                  8
# Venue                     H              H                  A
# Team            Sporting CP    Sporting CP        Sporting CP
# Opponent      Moreirense FC  Moreirense FC        Boavista FC
# Result                  3:0            3:0                1:2
# Position                 LW            NaN                NaN
# Minute                   34           90+5                 88
# At_score                2:0            3:0                1:2
# Type_of_goal       Solo run         Header  Right-footed shot
#
#                                     3                          4    \
# Unnamed: 0                            3                          4
# Goal_no                               4                          5
# Season                              2/3                        2/3
# Competition   TaÃ§a de Portugal Placard  TaÃ§a de Portugal Placard
# Matchday                   Fourth Round                Fifth Round
# Venue                                 H                          H
# Team                        Sporting CP                Sporting CP
# Opponent                   CD Estarreja    FC Oliveira do Hospital
# Result                              4:1                        8:1
# Position                            NaN                        NaN
# Minute                               67                         13
# At_score                            3:0                        3:0
# Type_of_goal           Left-footed shot                        NaN
#
#                             5                  6                  7    \
# Unnamed: 0                    5                  6                  7
# Goal_no                       6                  7                  8
# Season                      3/4                3/4                3/4
# Competition      Premier League             FA Cup     Premier League
# Matchday                     11        Fifth Round                 29
# Venue                         H                  H                  H
# Team          Manchester United  Manchester United  Manchester United
# Opponent          Portsmouth FC    Manchester City  Tottenham Hotspur
# Result                      3:0                4:2                3:0
# Position                     RW                 RW                NaN
# Minute                       80                 74                 89
# At_score                    2:0                3:0                2:0
# Type_of_goal   Direct free kick  Right-footed shot  Right-footed shot
#
#                             8                  9    ...  \
# Unnamed: 0                    8                  9  ...
# Goal_no                       9                 10  ...
# Season                      3/4                3/4  ...
# Competition      Premier League     Premier League  ...
# Matchday                     32                 38  ...
# Venue                         A                  A  ...
# Team          Manchester United  Manchester United  ...
# Opponent        Birmingham City        Aston Villa  ...
# Result                      1:2                0:2  ...
# Position                    NaN                NaN  ...
# Minute                       60                  4  ...
# At_score                    1:1                0:1  ...
# Type_of_goal             Header  Right-footed shot  ...
#
#                                  688                689                690  \
# Unnamed: 0                       688                689                690
# Goal_no                          689                690                691
# Season                         21/22              21/22              21/22
# Competition           Premier League     Premier League     Premier League
# Matchday                          18                 29                 29
# Venue                              H                  H                  H
# Team               Manchester United  Manchester United  Manchester United
# Opponent      Brighton & Hove Albion  Tottenham Hotspur  Tottenham Hotspur
# Result                           2:0                3:2                3:2
# Position                          CF                 CF                 CF
# Minute                            51                 12                 38
# At_score                         1:0                1:0                2:1
# Type_of_goal       Right-footed shot  Right-footed shot  Right-footed shot
#
#                             691                692                693  \
# Unnamed: 0                  691                692                693
# Goal_no                     692                693                694
# Season                    21/22              21/22              21/22
# Competition      Premier League     Premier League     Premier League
# Matchday                     29                 33                 33
# Venue                         H                  H                  H
# Team          Manchester United  Manchester United  Manchester United
# Opponent      Tottenham Hotspur       Norwich City       Norwich City
# Result                      3:2                3:2                3:2
# Position                     CF                 CF                 CF
# Minute                       81                  7                 32
# At_score                    3:2                1:0                2:0
# Type_of_goal             Header  Right-footed shot             Header
#
#                             694                695                696  \
# Unnamed: 0                  694                695                696
# Goal_no                     695                696                697
# Season                    21/22              21/22              21/22
# Competition      Premier League     Premier League     Premier League
# Matchday                     33                 34                 37
# Venue                         H                  A                  H
# Team          Manchester United  Manchester United  Manchester United
# Opponent           Norwich City         Arsenal FC         Chelsea FC
# Result                      3:2                3:1                1:1
# Position                     CF                 CF                 CF
# Minute                       76                 34                 62
# At_score                    3:2                2:1                1:1
# Type_of_goal   Direct free kick   Left-footed shot  Right-footed shot
#
#                             697
# Unnamed: 0                  697
# Goal_no                     698
# Season                    21/22
# Competition      Premier League
# Matchday                     35
# Venue                         H
# Team          Manchester United
# Opponent           Brentford FC
# Result                      3:0
# Position                     CF
# Minute                       61
# At_score                    2:0
# Type_of_goal            Penalty
#
# [13 rows x 698 columns]

# %%
#Sorting by an axis:
df.sort_index(axis=1, ascending=False)
# Out:
#     Venue  Unnamed: 0       Type_of_goal               Team Season Result  \
# 0       H           0           Solo run        Sporting CP    2/3    3:0
# 1       H           1             Header        Sporting CP    2/3    3:0
# 2       A           2  Right-footed shot        Sporting CP    2/3    1:2
# 3       H           3   Left-footed shot        Sporting CP    2/3    4:1
# 4       H           4                NaN        Sporting CP    2/3    8:1
# ..    ...         ...                ...                ...    ...    ...
# 693     H         693             Header  Manchester United  21/22    3:2
# 694     H         694   Direct free kick  Manchester United  21/22    3:2
# 695     A         695   Left-footed shot  Manchester United  21/22    3:1
# 696     H         696  Right-footed shot  Manchester United  21/22    1:1
# 697     H         697            Penalty  Manchester United  21/22    3:0
#
#     Position                 Opponent Minute      Matchday  Goal_no  \
# 0         LW            Moreirense FC     34             6        1
# 1        NaN            Moreirense FC   90+5             6        2
# 2        NaN              Boavista FC     88             8        3
# 3        NaN             CD Estarreja     67  Fourth Round        4
# 4        NaN  FC Oliveira do Hospital     13   Fifth Round        5
# ..       ...                      ...    ...           ...      ...
# 693       CF             Norwich City     32            33      694
# 694       CF             Norwich City     76            33      695
# 695       CF               Arsenal FC     34            34      696
# 696       CF               Chelsea FC     62            37      697
# 697       CF             Brentford FC     61            35      698
#
#                    Competition At_score
# 0                Liga Portugal      2:0
# 1                Liga Portugal      3:0
# 2                Liga Portugal      1:2
# 3    TaÃ§a de Portugal Placard      3:0
# 4    TaÃ§a de Portugal Placard      3:0
# ..                         ...      ...
# 693             Premier League      2:0
# 694             Premier League      3:2
# 695             Premier League      2:1
# 696             Premier League      1:1
# 697             Premier League      2:0
#
# [698 rows x 13 columns]

# %%
#Sorting by values:
df.sort_values(by='Team')
# Out:
#      Unnamed: 0  Goal_no Season                Competition      Matchday  \
# 611         611      612  19/20                    Serie A            16
# 647         647      648  20/21      UEFA Champions League   Group Stage
# 646         646      647  20/21      UEFA Champions League   Group Stage
# 645         645      646  20/21                    Serie A             8
# 644         644      645  20/21                    Serie A             8
# ..          ...      ...    ...                        ...           ...
# 4             4        5    2/3  TaÃ§a de Portugal Placard   Fifth Round
# 3             3        4    2/3  TaÃ§a de Portugal Placard  Fourth Round
# 2             2        3    2/3              Liga Portugal             8
# 1             1        2    2/3              Liga Portugal             6
# 0             0        1    2/3              Liga Portugal             6
#
#     Venue         Team                 Opponent Result Position Minute  \
# 611     H  Juventus FC           Udinese Calcio    3:1       CF     37
# 647     H  Juventus FC              Dynamo Kyiv    3:0       CF     57
# 646     H  Juventus FC          Ferencvarosi TC    2:1       CF     35
# 645     H  Juventus FC          Cagliari Calcio    2:0       CF     42
# 644     H  Juventus FC          Cagliari Calcio    2:0       CF     38
# ..    ...          ...                      ...    ...      ...    ...
# 4       H  Sporting CP  FC Oliveira do Hospital    8:1      NaN     13
# 3       H  Sporting CP             CD Estarreja    4:1      NaN     67
# 2       A  Sporting CP              Boavista FC    1:2      NaN     88
# 1       H  Sporting CP            Moreirense FC    3:0      NaN   90+5
# 0       H  Sporting CP            Moreirense FC    3:0       LW     34
#
#     At_score       Type_of_goal
# 611      2:0   Left-footed shot
# 647      2:0  Right-footed shot
# 646      1:1   Left-footed shot
# 645      2:0  Right-footed shot
# 644      1:0  Right-footed shot
# ..       ...                ...
# 4        3:0                NaN
# 3        3:0   Left-footed shot
# 2        1:2  Right-footed shot
# 1        3:0             Header
# 0        2:0           Solo run
#
# [698 rows x 13 columns]

# %% [markdown]
# # Selection

# %% [markdown]
# # Getting
# > Selecting a single column, which yields a Series, equivalent to df.A:

# %%
df['Team']
# Out:
# 0            Sporting CP
# 1            Sporting CP
# 2            Sporting CP
# 3            Sporting CP
# 4            Sporting CP
#              ...
# 693    Manchester United
# 694    Manchester United
# 695    Manchester United
# 696    Manchester United
# 697    Manchester United
# Name: Team, Length: 698, dtype: object

# %% [markdown]
# > Selecting via [], which slices the rows:

# %%
df[0:4]
# Out:
#    Unnamed: 0  Goal_no Season                Competition      Matchday Venue  \
# 0           0        1    2/3              Liga Portugal             6     H
# 1           1        2    2/3              Liga Portugal             6     H
# 2           2        3    2/3              Liga Portugal             8     A
# 3           3        4    2/3  TaÃ§a de Portugal Placard  Fourth Round     H
#
#           Team       Opponent Result Position Minute At_score  \
# 0  Sporting CP  Moreirense FC    3:0       LW     34      2:0
# 1  Sporting CP  Moreirense FC    3:0      NaN   90+5      3:0
# 2  Sporting CP    Boavista FC    1:2      NaN     88      1:2
# 3  Sporting CP   CD Estarreja    4:1      NaN     67      3:0
#
#         Type_of_goal
# 0           Solo run
# 1             Header
# 2  Right-footed shot
# 3   Left-footed shot

# %%
df[355:360]
# Out:
#      Unnamed: 0  Goal_no Season            Competition     Matchday Venue  \
# 355         355      356  13/14                 LaLiga           21     H
# 356         356      357  13/14           Copa del Rey  Semi-Finals     A
# 357         357      358  13/14           Copa del Rey  Semi-Finals     A
# 358         358      359  13/14  UEFA Champions League      last 16     A
# 359         359      360  13/14  UEFA Champions League      last 16     A
#
#             Team            Opponent Result Position Minute At_score  \
# 355  Real Madrid          Granada CF    2:0       LW     57      1:0
# 356  Real Madrid  Atlatico de Madrid    0:2       LW      6      0:1
# 357  Real Madrid  Atlatico de Madrid    0:2       LW     15      0:2
# 358  Real Madrid        FC Schalke 4    1:6       LW     52      0:3
# 359  Real Madrid        FC Schalke 4    1:6       LW     89      0:6
#
#           Type_of_goal
# 355  Right-footed shot
# 356            Penalty
# 357            Penalty
# 358   Left-footed shot
# 359  Right-footed shot

# %% [markdown]
# # Selection by label
# > For getting a cross section using a label:

# %%
df1 = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df1
# Out:
#                    A         B         C         D
# 2013-01-01  1.750147 -1.005009  2.396692  0.823300
# 2013-01-02  1.582759  0.899979  0.842661  1.589764
# 2013-01-03 -0.721107  0.465468  1.227007 -0.841115
# 2013-01-04  1.754927 -0.465076 -0.567563 -0.964918
# 2013-01-05 -0.004276 -2.629235  0.236795  1.401008
# 2013-01-06  0.109809 -1.038205  1.393569 -0.207766

# %%
df1.loc[dates[0]]
# Out:
# A    1.907897
# B    0.416196
# C    0.160157
# D    0.735555
# Name: 2013-01-01 00:00:00, dtype: float64

# %% [markdown]
# > Selecting on a multi-axis by label:

# %%
df1.loc[:, ["A", "B"]]
# here first  : defines all the value, ["A", "B"] defines A & B columns. That means [:, ["A", "B"]] defines all the values from column A & B
# Out:
#                    A         B
# 2013-01-01  1.907897  0.416196
# 2013-01-02  1.452866  0.301314
# 2013-01-03 -1.223501 -0.373056
# 2013-01-04  0.244675 -1.302855
# 2013-01-05  0.774055  0.875841
# 2013-01-06  0.970371  0.776456

# %% [markdown]
# > Showing label slicing, both endpoints are included:

# %%
df1.loc['2013-01-02':'2013-01-05',['A','B']]
# Out:
#                    A         B
# 2013-01-02 -0.200456  1.522654
# 2013-01-03 -0.518521  0.719187
# 2013-01-04  0.778570  1.003627
# 2013-01-05  0.421893  0.092500

# %% [markdown]
# > Reduction in the dimensions of the returned object: ডাইমে্নশন পরিবর্তন হবে। অর্থাৎ কলাম রো তে চলে যাবে।

# %%
df1.loc['2013-01-02', ['A','B']]
# Out:
# A    1.582759
# B    0.899979
# Name: 2013-01-02 00:00:00, dtype: float64

# %% [markdown]
# > For getting a scalar value:

# %%
df1.loc[dates[0], 'A']
# Out:
# 1.7501473838168196

# %% [markdown]
# > For getting fast access to a scalar (equivalent to the prior method):

# %%
df1.at[dates[0], 'A']
# Out:
# 1.7501473838168196

# %% [markdown]
# # Selection by position

# %% [markdown]
# > Select via the position of the passed integers:

# %%
df1.iloc[3]
# Out:
# A    1.754927
# B   -0.465076
# C   -0.567563
# D   -0.964918
# Name: 2013-01-04 00:00:00, dtype: float64

# %% [markdown]
# > By integer slices, acting similar to NumPy/Python:

# %%
df1.iloc[2:5, 0:3]
# Out:
#                    A         B         C
# 2013-01-03 -0.721107  0.465468  1.227007
# 2013-01-04  1.754927 -0.465076 -0.567563
# 2013-01-05 -0.004276 -2.629235  0.236795

# %% [markdown]
# > By lists of integer position locations, similar to the NumPy/Python style:

# %%
df1.iloc[[1,2,3], 0:2]
# Out:
#                    A         B
# 2013-01-02  1.582759  0.899979
# 2013-01-03 -0.721107  0.465468
# 2013-01-04  1.754927 -0.465076

# %% [markdown]
# > For slicing rows explicitly:

# %%
df1.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  1.582759  0.899979  0.842661  1.589764
# 2013-01-03 -0.721107  0.465468  1.227007 -0.841115

# %% [markdown]
# > For slicing columns explicitly:

# %%
df1.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -1.005009  2.396692
# 2013-01-02  0.899979  0.842661
# 2013-01-03  0.465468  1.227007
# 2013-01-04 -0.465076 -0.567563
# 2013-01-05 -2.629235  0.236795
# 2013-01-06 -1.038205  1.393569

# %% [markdown]
# > For getting a value explicitly:

# %%
df1.iloc[1, 1]
# Out:
# 0.8999791578895616

# %% [markdown]
# > For getting fast access to a scalar (equivalent to the prior method):

# %%
df1.iat[1, 1]
# Out:
# 0.8999791578895616

# %% [markdown]
# # Boolean indexing

# %% [markdown]
# > Using a single column’s values to select data:

# %%
df1[df1['A'] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.750147 -1.005009  2.396692  0.823300
# 2013-01-02  1.582759  0.899979  0.842661  1.589764
# 2013-01-04  1.754927 -0.465076 -0.567563 -0.964918
# 2013-01-06  0.109809 -1.038205  1.393569 -0.207766
